# %%
from src.imageclass import ImageToLMS

# %%
converter = ImageToLMS("notebooks/images/red.jpg")
lms_image = converter.get_lms_activations()

print(lms_image.shape)   # (H, W, 3)
print(lms_image[100, 100])  # [L, M, S] activation for one pixel
# Out:
# (960, 960, 3)
# [0.31397088 0.15537241 0.01775239]
